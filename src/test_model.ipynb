# %% [markdown]
# # Image Detection

# %%
# !python3 detect.py --source ./custom_dataset/test_images/test1.png --weights ./runs/train/emergency-vehicle-detection2/weights/best.pt
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.25, device='', exist_ok=False, img_size=640, iou_thres=0.45, name='exp', no_trace=False, nosave=False, project='runs/detect', save_conf=False, save_txt=False, source='./custom_dataset/test_images/test1.png', update=False, view_img=False, weights=['./runs/train/emergency-vehicle-detection2/weights/best.pt'])
# YOLOR 🚀 v0.1-115-g072f76c torch 1.10.1+cu102 CUDA:0 (GeForce RTX 2080 Ti, 11019.4375MB)
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
# /home/ubuntu/.local/lib/python3.6/site-packages/torch/functional.py:445: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2157.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Model Summary: 314 layers, 36492560 parameters, 6194944 gradients, 103.2 GFLOPS
# ...

# %%
# !python3 detect.py --source ./custom_dataset/test_images/test2.png --weights ./runs/train/emergency-vehicle-detection2/weights/best.pt
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.25, device='', exist_ok=False, img_size=640, iou_thres=0.45, name='exp', no_trace=False, nosave=False, project='runs/detect', save_conf=False, save_txt=False, source='./custom_dataset/test_images/test2.png', update=False, view_img=False, weights=['./runs/train/emergency-vehicle-detection2/weights/best.pt'])
# YOLOR 🚀 v0.1-115-g072f76c torch 1.10.1+cu102 CUDA:0 (GeForce RTX 2080 Ti, 11019.4375MB)
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
# /home/ubuntu/.local/lib/python3.6/site-packages/torch/functional.py:445: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2157.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Model Summary: 314 layers, 36492560 parameters, 6194944 gradients, 103.2 GFLOPS
# ...

# %% [markdown]
# # Image Detection with Cropping the Siren Light Part

# %%
# !python3 detect-crop-siren.py --source ./custom_dataset/test_images/test1.png --weights ./runs/train/emergency-vehicle-detection2/weights/best.pt --name 220118
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.25, device='', exist_ok=False, img_size=640, iou_thres=0.45, name='220118', no_trace=False, nosave=False, project='runs/detect', save_conf=False, save_txt=False, source='./custom_dataset/test_images/test1.png', update=False, view_img=False, weights=['./runs/train/emergency-vehicle-detection2/weights/best.pt'])
# YOLOR 🚀 v0.1-115-g072f76c torch 1.10.1+cu102 CUDA:0 (GeForce RTX 2080 Ti, 11019.4375MB)
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
# /home/ubuntu/.local/lib/python3.6/site-packages/torch/functional.py:445: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2157.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# ...

# %% [markdown]
# # Video Detection

# %%
# !python3 detect.py --conf-thres 0.5 --source ./custom_dataset/test_videos/test_video1.mp4 --weights ./runs/train/emergency-vehicle-detection2/weights/best.pt
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.5, device='', exist_ok=False, img_size=640, iou_thres=0.45, name='exp', no_trace=False, nosave=False, project='runs/detect', save_conf=False, save_txt=False, source='./custom_dataset/test_videos/test_video1.mp4', update=False, view_img=False, weights=['./runs/train/emergency-vehicle-detection2/weights/best.pt'])
# YOLOR 🚀 v0.1-115-g072f76c torch 1.10.1+cu102 CUDA:0 (GeForce RTX 2080 Ti, 11019.4375MB)
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
# /home/ubuntu/.local/lib/python3.6/site-packages/torch/functional.py:445: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2157.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# ...

# %%
# !python3 detect.py --conf-thres 0.5 --source ./custom_dataset/test_videos/test_video2.mp4 --weights ./runs/train/emergency-vehicle-detection2/weights/best.pt
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.5, device='', exist_ok=False, img_size=640, iou_thres=0.45, name='exp', no_trace=False, nosave=False, project='runs/detect', save_conf=False, save_txt=False, source='./custom_dataset/test_videos/test_video2.mp4', update=False, view_img=False, weights=['./runs/train/emergency-vehicle-detection2/weights/best.pt'])
# YOLOR 🚀 v0.1-115-g072f76c torch 1.10.1+cu102 CUDA:0 (GeForce RTX 2080 Ti, 11019.4375MB)
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
# /home/ubuntu/.local/lib/python3.6/site-packages/torch/functional.py:445: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2157.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# ...
